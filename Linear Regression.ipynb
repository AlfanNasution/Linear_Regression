# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas import DataFrame

from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('cost_revenue_clean.csv')
df
# Out:
#       production_budget_usd  worldwide_gross_usd
# 0                 1000000.0         2.600000e+01
# 1                   10000.0         4.010000e+02
# 2                  400000.0         4.230000e+02
# 3                  750000.0         4.500000e+02
# 4                   10000.0         5.270000e+02
# ...                     ...                  ...
# 5029            225000000.0         1.519480e+09
# 5030            215000000.0         1.671641e+09
# 5031            306000000.0         2.058662e+09
# 5032            200000000.0         2.207616e+09
# 5033            425000000.0         2.783919e+09
#
# [5034 rows x 2 columns]

# %%
df.describe()
# Out:
#        production_budget_usd  worldwide_gross_usd
# count           5.034000e+03         5.034000e+03
# mean            3.290784e+07         9.515685e+07
# std             4.112589e+07         1.726012e+08
# min             1.100000e+03         2.600000e+01
# 25%             6.000000e+06         7.000000e+06
# 50%             1.900000e+07         3.296202e+07
# 75%             4.200000e+07         1.034471e+08
# max             4.250000e+08         2.783919e+09

# %%
2.78e+09
# Out:
# 2780000000.0

# %%
x = pd.DataFrame(df, columns=['production_budget_usd'])
y = pd.DataFrame(df, columns=['worldwide_gross_usd'])

# %%
plt.figure(figsize=(10,6))
plt.scatter(x,y,alpha=0.3)
plt.title('Prodution Budget vs Worldwide Gross')
plt.xlabel('Production Budget')
plt.ylabel('Worldwide Gross')
plt.ylim(0,3000000000)
plt.xlim(0,450000000)
# Out:
# (0.0, 450000000.0)

# %%
regression = LinearRegression()

# %%
regression.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# Slope Coefficient:

# %%
regression.coef_ #theta_1
# Out:
# array([[3.11150918]])

# %%
#intercept
regression.intercept_
# Out:
# array([-7236192.72913958])

# %%
#Plot the Linear Regression into The Canvas

plt.figure(figsize=(10,6))
plt.scatter(x,y,alpha=0.3)
plt.plot(x, regression.predict(x), color='r', lw=3)

plt.title('Prodution Budget vs Worldwide Gross')
plt.xlabel('Production Budget')
plt.ylabel('Worldwide Gross')
plt.ylim(0, 3000000000)
plt.xlim(0, 450000000)
# Out:
# (0.0, 450000000.0)

# %%
regression.score(x,y)
# Out:
# 0.5496485356985729
